# %%
import osmnx as ox
import networkx as nx
import numpy as np
import pandas as pd

import geopandas as gpd
from shapely.geometry import Polygon

# %%
graph = ox.graph_from_bbox(south=45.5049722, north=45.5412594, west=-73.6120455, east=-73.5593741)
fig, ax = ox.plot_graph(graph)

# %%
graph.size()
# Out:
# 11023
